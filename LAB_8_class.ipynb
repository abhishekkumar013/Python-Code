# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
plt.plot([1,2,3,4])
plt.ylabel('Some Number on Y')
plt.xlabel('Some Number on X')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'b--')
plt.axis((0,6,0,20))
plt.ylabel('square root Y')
plt.xlabel('Some Number on X')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'rs')
plt.axis((0,6,0,20))
plt.ylabel('square root Y')
plt.xlabel('Some Number on X')
plt.show()

# %%
t=np.arange(0,5,0.2)
print(t)

plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g*')
plt.show()
# Out:
# [0.  0.2 0.4 0.6 0.8 1.  1.2 1.4 1.6 1.8 2.  2.2 2.4 2.6 2.8 3.  3.2 3.4
#  3.6 3.8 4.  4.2 4.4 4.6 4.8]

# %%
plt.plot([1,2,3,4],[1,2,9,16],'r--',[1,2,3,4],[1,8,27,61],'b-')
plt.axis((0,6,0,20))
plt.show()

# %%
data={'a':[0,1,2,3,4,5],'b':[0,1,4,9,16,25]}
plt.plot('a','b',data=data)
plt.xlabel('a label')
plt.ylabel('b label')
plt.show()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_21624\1434453007.py:2: RuntimeWarning: Second argument 'b' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot('a','b',data=data)

# %% [markdown]
# # scaterplot

# %%
data={'a':np.arange(50),'c':np.random.randint(0,50,50),'d':np.random.randn(50)}
data['b']=data['a']+10*np.random.randn(50)
data['d']=np.abs(data['d'])*100


plt.scatter('a','b',c='a',s='a',data=data)
plt.show()

# %%
df=sns.load_dataset('titanic')

sns.barplot(y='age',x='sex',data=df)
plt.show()

# %%
df=sns.load_dataset('titanic')

sns.barplot(y='age',x='sex',hue='alone',data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 3
#       1 df=sns.load_dataset('titanic')
# ----> 3 sns.barplot(y='age',x='sex',hue='alone',data=df)
#       4 plt.show()
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2763, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2760 if ax is None:
#    2761     ax = plt.gca()
# -> 2763 plotter.plot(ax, kwargs)
#    2764 return ax
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
df=sns.load_dataset('titanic')

sns.histplot(data=df,x="age",kde=True)
plt.show()

# %%
df=sns.load_dataset('titanic')

sns.boxplot(data=df,x="sex",y="age")
plt.show()

# %%
data=[[46,30],[68,40]]
sns.heatmap(data=data)
plt.show()

# %%
#----preprocessing-----------------------------
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import classification_report

# %%
import pandas as pd

# %%
col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']
pima = pd.read_csv("diabetes.csv", header=None, names=col_names)

# %%
print(pima.head())
# Out:
#    pregnant  glucose    bp  skin  insulin   bmi  pedigree  age  label
# 0         6      148  72.0    35        0  33.6     0.627   50      1
# 1         1       85  66.0    29        0  26.6     0.351   31      0
# 2         8      183  64.0     0        0  23.3     0.672   32      1
# 3         1       89  66.0    23       94  28.1     0.167   21      0
# 4         0      137  40.0    35      168  43.1     2.288   33      1

# %%
feature_cols = ['pregnant', 'insulin', 'bmi', 'age','glucose','bp','pedigree']
X = pima[feature_cols] 
y = pima.label
